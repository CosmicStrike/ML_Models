# %%
import pandas as pd
import numpy as np
import seaborn as sb

# %%
df = pd.read_excel('Dataset/abalone.xlsx')
print(type(df))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
df.head()
# Out:
#   Sex  Length  Diameter  Height  Whole Weight  Shucked Weight  Viscera weight  \
# 0   M   0.455     0.365   0.095        0.5140          0.2245          0.1010
# 1   M   0.350     0.265   0.090        0.2255          0.0995          0.0485
# 2   F   0.530     0.420   0.135        0.6770          0.2565          0.1415
# 3   M   0.440     0.365   0.125        0.5160          0.2155          0.1140
# 4   I   0.330     0.255   0.080        0.2050          0.0895          0.0395
#
#    shell weight  rings
# 0         0.150     15
# 1         0.070      7
# 2         0.210      9
# 3         0.155     10
# 4         0.055      7

# %%
df.describe()
# Out:
#             Length     Diameter       Height  Whole Weight  Shucked Weight  \
# count  4177.000000  4177.000000  4177.000000   4177.000000     4177.000000
# mean      0.523992     0.407881     0.139516      0.828742        0.359367
# std       0.120093     0.099240     0.041827      0.490389        0.221963
# min       0.075000     0.055000     0.000000      0.002000        0.001000
# 25%       0.450000     0.350000     0.115000      0.441500        0.186000
# 50%       0.545000     0.425000     0.140000      0.799500        0.336000
# 75%       0.615000     0.480000     0.165000      1.153000        0.502000
# max       0.815000     0.650000     1.130000      2.825500        1.488000
#
#        Viscera weight  shell weight        rings
# count     4177.000000   4177.000000  4177.000000
# mean         0.180594      0.238831     9.933684
# std          0.109614      0.139203     3.224169
# min          0.000500      0.001500     1.000000
# ...

# %%
sb.lineplot(x=df['Height'], y=df['rings'])
# Out:
# <AxesSubplot:xlabel='Height', ylabel='rings'>

# %%
sb.regplot(x=df['Height'], y=df['rings'])
# Out:
# <AxesSubplot:xlabel='Height', ylabel='rings'>

# %%
sb.lmplot(x='Height', y='rings', data=df)

# %%
sb.histplot(df['rings'])
# Out:
# <AxesSubplot:xlabel='rings', ylabel='Count'>

# %%
sb.countplot(x='rings', data=df)
# Out:
# <AxesSubplot:xlabel='rings', ylabel='count'>

# %%
sb.pairplot(df)

# %%
x = df.corr()
print(x['rings'])
# Out:
# Length            0.556720
# Diameter          0.574660
# Height            0.557467
# Whole Weight      0.540390
# Shucked Weight    0.420884
# Viscera weight    0.503819
# shell weight      0.627574
# rings             1.000000
# Name: rings, dtype: float64

# %%
df["length_height"] = df['Length']*df["Height"]
print(df["length_height"])
# Out:
# 0       0.043225
# 1       0.031500
# 2       0.071550
# 3       0.055000
# 4       0.026400
#           ...
# 4172    0.093225
# 4173    0.079650
# 4174    0.123000
# 4175    0.093750
# 4176    0.138450
# Name: length_height, Length: 4177, dtype: float64

# %%
def cor():
    x = df.corr()
    print(x['rings'])

# %%
df.drop('Length', inplace=True ,axis=1)
df.drop('Height', inplace=True ,axis=1)
cor()
# Out:
# Diameter          0.574660
# Whole Weight      0.540390
# Shucked Weight    0.420884
# Viscera weight    0.503819
# shell weight      0.627574
# rings             1.000000
# length_height     0.564932
# Name: rings, dtype: float64

# %%
sb.pairplot(df)

# %%
# label = df['rings']
# df.drop(columns='rings', inplace=True, axis=1)

# %%
from sklearn.preprocessing import OneHotEncoder

encoder = OneHotEncoder()
df = encoder.fit_transform(df)

# %%
from sklearn import linear_model
from sklearn.model_selection import train_test_split

# x_train, x_test, y_train, y_test = train_test_split(df, , test_size=0.2, train_size=0.8)
# Out:
#   (0, 2)	1.0
#   (0, 59)	1.0
#   (0, 829)	1.0
#   (0, 2960)	1.0
#   (0, 4257)	1.0
#   (0, 5201)	1.0
#   (0, 5878)	1.0
#   (0, 6179)	1.0
#   (1, 2)	1.0
#   (1, 39)	1.0
#   (1, 399)	1.0
#   (1, 2721)	1.0
#   (1, 4152)	1.0
#   (1, 5051)	1.0
#   (1, 5870)	1.0
#   (1, 6085)	1.0
#   (2, 0)	1.0
#   (2, 70)	1.0
#   (2, 1076)	1.0
#   (2, 3023)	1.0
#   (2, 4338)	1.0
#   (2, 5312)	1.0
#   (2, 5872)	1.0
#   (2, 6409)	1.0
#   (3, 2)	1.0
#   :	:
#   (4173, 6479)	1.0
#   (4174, 2)	1.0
#   (4174, 81)	1.0
#   (4174, 1841)	1.0
#   (4174, 3537)	1.0
#   (4174, 4629)	1.0
#   (4174, 5488)	1.0
#   (4174, 5872)	1.0
#   (4174, 6807)	1.0
#   (4175, 0)	1.0
#   (4175, 83)	1.0
#   (4175, 1724)	1.0
#   (4175, 3548)	1.0
#   (4175, 4576)	1.0
#   (4175, 5468)	1.0
#   (4175, 5873)	1.0
#   (4175, 6590)	1.0
#   (4176, 2)	1.0
#   (4176, 97)	1.0
#   (4176, 2462)	1.0
#   (4176, 4004)	1.0
#   (4176, 4790)	1.0
#   (4176, 5751)	1.0
#   (4176, 5875)	1.0
#   (4176, 6901)	1.0

# %%
print(x_train, y_train)
model = linear_model.LinearRegression()
# Out:
#       Sex  Diameter  Whole Weight  Shucked Weight  Viscera weight  \
# 28      2     0.475        0.9365          0.3940          0.2190
# 370     0     0.545        1.5660          0.6645          0.3455
# 1689    2     0.475        1.0845          0.5005          0.2355
# 3022    1     0.370        0.3965          0.1485          0.0855
# 578     1     0.445        0.8865          0.3830          0.2090
# ...   ...       ...           ...             ...             ...
# 3191    2     0.515        1.3315          0.5665          0.3470
# 3200    0     0.405        0.6835          0.2710          0.1450
# 3802    1     0.230        0.1455          0.0595          0.0305
# 3560    2     0.470        1.1860          0.6355          0.2315
# 1503    0     0.490        1.3360          0.6805          0.2590
#
#       shell weight  length_height
# 28          0.2950       0.108900
# 370         0.4150       0.107250
# 1689        0.3105       0.100000
# ...

# %%
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
import math
prediction = model.predict(x_test)
for i in range(len(prediction)):
    prediction[i] = int(prediction[i])

# %%
x_test['prediction'] = prediction

# %%
l = [i for i in range(0, len(x_test))]
sb.lineplot(prediction, l)
# Out:
# d:\Shubham_File_\MachineLearning_MyProjects\MODELS\VENV\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:>

# %%
sb.lineplot(y_test, l)
# Out:
# d:\Shubham_File_\MachineLearning_MyProjects\MODELS\VENV\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:>

# %%
from sklearn import metrics

metrics.accuracy_score(y_test, prediction)
# Out:
# 0.2452153110047847
